# %% [markdown]
# # Random Easy Analysis

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
import matplotlib.pyplot as plt

from utils.plotting import plot_rewards, plot_performances, plot_velocities

# %%
plt.figure(figsize=(15, 12))

# %% [markdown]
# ## Training

# %%
# Get paths and Load data

EXPERIMENT = "random_easy"
LOG_DIR = Path("../logs/train/")

metrics_path = LOG_DIR / f"{EXPERIMENT}_training_metrics.csv"
rewards_path = LOG_DIR / f"{EXPERIMENT}_reward_components.csv"

df_metrics = pd.read_csv(metrics_path)
df_rewards = pd.read_csv(rewards_path)

# %%
plot_rewards(df=df_rewards, path=str(PROJECT_ROOT / "figures" / "train"), file_name=EXPERIMENT, window=10, render=True)

# %%
plot_performances(df=df_metrics, path=str(PROJECT_ROOT / "figures" / "train"), file_name=EXPERIMENT, window=10, render=True)

# %%
plot_velocities(df=df_metrics, path=str(PROJECT_ROOT / "figures" / "train"), file_name=EXPERIMENT, window=10, render=True)

# %% [markdown]
# ## Evaluation

# %%
# Get paths and Load data

EXPERIMENT = "random_hard"
LOG_DIR = Path("../logs/eval/")

metrics_path = LOG_DIR / f"{EXPERIMENT}_training_metrics.csv"
rewards_path = LOG_DIR / f"{EXPERIMENT}_reward_components.csv"

df_metrics = pd.read_csv(metrics_path)
df_rewards = pd.read_csv(rewards_path)

# %%
plot_rewards(df=df_rewards, path=str(PROJECT_ROOT / "figures" / "eval"), file_name=EXPERIMENT, window=10, render=True)

# %%
plot_performances(df=df_metrics, path=str(PROJECT_ROOT / "figures" / "eval"), file_name=EXPERIMENT, window=10, render=True)

# %%
plot_velocities(df=df_metrics, path=str(PROJECT_ROOT / "figures" / "eval"), file_name=EXPERIMENT, window=10, render=True)
